# %%
#OOPs Library

class Library:
    
    def __init__(self, list, name):
        self.booklist = list
        self.booklists = list.copy()
        self.name = name
        self.bookdict = {}
    
    
    def displayfull(self):
        print(f'{self.name} has following books in his Kutubkhana')
        for book in self.booklists:
            print(book)
            
            
    def displayBooks(self):
        print(f'{self.name} has following books available in his Kutubkhana')
        for book in self.booklist:
            print(book)
            
    def display(self):
        print(f'{self.name} has following landing books in his Kutubkhana')
        for book in self.bookdict:
            print(book)
    
    def addBook(self,book):
        self.booklist.append(book)
        self.booklists.append(book)
        print('book has been added')
        
    
    def lendBook(self,user,book):
        if book not in self.bookdict.keys():
            self.bookdict.update({book:user})
            self.booklist.remove(book)
            print('Book issue  for you you can take now')
        else:
            print(f'Book already being used by {self.bookdict[book]}')
    
    def returnBook(self, book):
        self.bookdict.pop(book)
        self.booklist.append(book)
        print('your book return successfully')
    

kutub = Library(['Har','Bukhari Sharif', 'Muslim Sharif', 'Abudaud', 'Sunan Tirmizi', 'Sunan anasai', 'Sunan ibne-maja', 'Tahavi Sharif'],"Jamiya Naziriya Kakoshi")

while(True):
    print(f'Welcome to the {kutub.name} library')
    print('Enter your choices')
    print('0. Display book')
    print('1. Display available book')
    print('2. Add book')
    print('3. Lend book')
    print('4. Return book')
    print('5. lending books')
    
    user_choice = int(input())
    if user_choice == 0:
        kutub.displayfull()
        
    elif user_choice == 1:
        kutub.displayBooks()
        
    elif user_choice == 2:
        book = input('Enter book name which you want to add')
        kutub.addBook(book)
        
    elif user_choice == 3:
        book = input('Enter book name which you want to lend')
        user = input('Enter your name')
        kutub.lendBook(user,book)
        
    elif user_choice == 4:
        book = input('Enter book name which you want to return:')
        kutub.returnBook(book)
        
    elif user_choice == 5:
        kutub.display()
        
    else:
        print('Enter a valid choice')
        
        
    print('Enter "q" to quit and "c" to continue')
    user_choice2 = ''
    while(user_choice2 !='q' and user_choice2 != 'c'):
        
        user_choice2 = input()
        if user_choice == 'q':
            exit()
        if user_choice == 'c':
            continue
# Out:
# Welcome to the Jamiya Naziriya Kakoshi library
# Enter your choices
# 0. Display book
# 1. Display available book
# 2. Add book
# 3. Lend book
# 4. Return book
# 5. lending books
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 60
#      57 print('4. Return book')
#      58 print('5. lending books')
# ---> 60 user_choice = int(input())
#      61 if user_choice == 0:
#      62     kutub.displayfull()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
class BankAccount:

    no_of_cust = 0
    acc_num = 42010

    def __init__(self, name, mobile_no, initial_depo, pin):
        
        self.name                 = name
        self.cust_acc_num         = BankAccount.acc_num
        self.mobile_no            = mobile_no
        self.acc_balance          = initial_depo
        self.pin                  = pin
        
        BankAccount.acc_num       = BankAccount.acc_num + 1
        BankAccount.no_of_cust    = BankAccount.no_of_cust + 1

    def basic_details(self):
        print(f'User: {self.name}\t Account No: {self.cust_acc_num}\t Balance: ₹{self.acc_balance}')

    def deposit(self):
        amount = int(input('Enter the deposit amount: '))
        if amount > 0:
            self.acc_balance      = self.acc_balance + amount
            print(f'Transaction completed. Current Balance: ₹{self.acc_balance}')
        else:
            print('Invalid amount transaction aborted')

    def withdrawl(self):
        amount = int(input('Enter the withdrawl amount: '))
        if amount <= self.acc_balance and amount > 0:
            self.acc_balance      = self.acc_balance - amount
            print(f'Transaction completed. Current Balance: ₹{self.acc_balance}')
        else:
            print('Invalid amount transaction aborted')

    def payment(self, other):
        amount = int(input('Enter the payment amount: '))
        if amount <= self.acc_balance and amount > 0:
            self.acc_balance      = self.acc_balance - amount
            other.acc_balance     = other.acc_balance + amount
            print(f'Transaction completed. Current Balance: ₹{self.acc_balance}')
        else:
            print('Invalid amount transaction aborted')

customer_dict = {}             # use account no. as key and class object(customer account) as value
mobile_acc_link = {}           # use mobile no. as key and store account no. as value, for linking purpose 

def new_cust():
    name = input('Enter the name of customer: ')
    mobile_no = int(input('Enter the mobile number of customer: '))
    initial_depo = int(input('Enter the initial deposit amount: '))
    if initial_depo <= 0:
        print('Invalid Amount')
        return
    pin = int(input('Create PIN: '))
    customer = BankAccount(name=name, mobile_no=mobile_no, initial_depo=initial_depo, pin=pin)
    customer_dict[customer.cust_acc_num] = customer                  # acct. no. stored as key and oject as value    
    mobile_acc_link[customer.mobile_no] = customer.cust_acc_num      # mobile no. linked
    print('New User Created!')
    print(f'Welcome {customer.name} to Al-Bahrain Bank. {customer.cust_acc_num} is your account number')

def login():
    account_no = int(input('Enter your Account Number: '))
    account_pin = int(input('Enter your Account PIN: '))
    if account_no in customer_dict.keys() and account_pin == customer_dict[account_no].pin :
        print(f'\n{customer_dict[account_no].name} Logged in')
        customer_dict[account_no].basic_details()
    else:
        print('Account either not exist or the pin is wrong')
        return
    while True:
        user_input1 = input('''Press 1 for deposit:
Press 2 for withdrawl:
Press 3 for money transfer:
Press 4 to log out\n''')
        if user_input1 == '1':
            customer_dict[account_no].deposit()
        elif user_input1 == '2':
            customer_dict[account_no].withdrawl()
        elif user_input1 == '3':
            mobile = int(input('Enter the mobile number of recepient: '))
            if mobile in mobile_acc_link.keys():
                secondary = mobile_acc_link[mobile]             
                customer_dict[account_no].payment(customer_dict[secondary])
            else:
                print('The mobile number you have enter does not have an account associated with it')
        elif user_input1 == '4':
            print('Logged Out')
            return
        else:
            print('Invalid input try again')
        print('\n#############################################################\n')
        customer_dict[account_no].basic_details()


while True:
    user_input1 = input('''Press 1 for creating a new customer:
Press 2 for logging in as an existing customer:
Press 3 for displaying number of customers:
Press 4 for exit\n''')

    if user_input1 == '1':
        print('Create user')
        new_cust()
    elif user_input1 == '2':
        login()
    elif user_input1 == '3':
        print('There currently', BankAccount.no_of_cust,'customers in Al-Bahrain bank.')
        
    elif user_input1 == '4':
        print('Exited')
        break
    else:
        print('Invalid input try again')
    print('\n*************************************************************\n')

# %%
string='ljkhg2334ftdresaw234567890-@#$%^356^&&*'
num = []
alpha = []
chra = []

for i in string:
    if i.isnumeric():
        num.append(i)
    elif i.isalpha():
        alpha.append(i)
    else:
        chra.append(i)
    
        
print("".join(num))
print("".join(alpha))
print("".join(chra))

# %%
a = "hjdadjsnd"
b = 123
c = '123.23', 'ahsjashjak', '12'
d = ['123.23', 'ahsjashjak', '12']
f = {'123.23', 'ahsjashjak', '12'}
e = {'fname':'haris','lname':'rafik','sname':'sulliya'}
for x in range(len(e)):
    print(x)

# %%
import smtplib

sender_mail = 'abuharissuliya@gmail.com'
receiver_mail = [abuharissulliya@gmail.com]
message = '''From: From person %s
To: To person %s
Subject: Sending SMTP e-mail   
This is a test e-mail message.
'''%(sender_mail,receiver_mail)
try:    
   password = input('Enter the password');    
   smtpObj = smtplib.SMTP('gmail.com',587)    
   smtpobj.login(sender_mail,password)    
   smtpObj.sendmail(sender_mail, receivers_mail, message)    
   print("Successfully sent email")    
except Exception:    
   print("Error: unable to send email")
# Out:
#   Cell In [4], line 10
#     try:
#         ^
# SyntaxError: invalid non-printable character U+00A0

# %%
def add (a,b):
    return a+b
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 3
#       1 def add (a,b):
#       2     return a+b
# ----> 3 add()
#
# TypeError: add() missing 2 required positional arguments: 'a' and 'b'

# %%
def my_add(a, b):
    result = a + b 
    print(f"{a} + {b} = {result}")
    return result

from functools import reduce

numbers = [0, 1, 2, 3, 4]
reduce(my_add, numbers)
# Out:
# 0 + 1 = 1
# 1 + 2 = 3
# 3 + 3 = 6
# 6 + 4 = 10
# 10

# %%
a = ['Haris','Huzaifa','Hanjala']
b = ['Haris','Huzaifa','Hanjala']

print(id(a))
print(id(b))

c = ('Haris','Huzaifa','Hanjala')
d = ('Haris','Huzaifa','Hanjala')

print(id(c))
print(id(d))

a = 25
b = 25

print(id(a))
print(id(b))

a = 'Haris'
b = 'Haris'

print(id(a))
print(id(b))
# Out:
# 1769395326784
# 1769395118144
# 1769395177472
# 1769395115392
# 140707808990760
# 140707808990760
# 1769395117360
# 1769395117360

# %%
def add(name):
    def show(mes):
        return mes+" "+name
    return show
a=add("Haris")
a("hello")
a("Hii")

b=add("Junaid")
b("ass")
# Out:
# 'ass Junaid'
